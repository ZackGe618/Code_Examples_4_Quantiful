# %% [markdown]
# # Assignment 1a

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### a

# %% [markdown]
# The total size of the entire folder is 2.6T. To get the size figure, we can list files with option -s, which prints the size. Also, option -h can convert the figure to be human-readable.

# %%
ls -lstrh /mnt/data/MetService_WRF/
# Out:
# total 2.6T
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20000101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RAINNC_20000201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20000301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20000401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20000501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20000601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20000701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20000801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20000901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20001001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20001101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20001201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20010101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20010201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20010301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20010401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20010501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20010601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20010701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20010801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20010901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20011001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20011101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20011201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20020101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20020201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20020301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20020401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20020501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20020601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20020701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20020801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20020901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20021001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20021101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20021201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20030101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20030201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20030301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20030401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20030501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20030601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20030701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20030801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20030901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20031001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20031101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20031201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20040101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RAINNC_20040201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20040301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20040401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20040501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20040601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20040701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20040801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20040901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20041001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20041101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20050201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20050301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20050401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20050501000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20050701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20050801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20050901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20051001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20051101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20051201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20060101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20060201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20060301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20060401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20060501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20060601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20060701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20060801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20060901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20061001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20061101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20061201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20070101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20070201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20070301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20070401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20070501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20070601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20070701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20070801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20070901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20071001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20071101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20071201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20080101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RAINNC_20080201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20080301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20080401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20080501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20080601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20080701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20080801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20080901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20081001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20081101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20081201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20090101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20090201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20090301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20090401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20090501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20090601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20090701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20090801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20090901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20091001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20091101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20091201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20100101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20100201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20100301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20100401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20100501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20100601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20100701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20100801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20100901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20101001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20101101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20101201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20110101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20110201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20110301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20110401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20110501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20110601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20110701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20110801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20110901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20111001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20111101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20111201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20120101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RAINNC_20120201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20120301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20120401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20120501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20120601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20120701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20120801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20120901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20121001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20121101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20121201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20130101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20130201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20130301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20130401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20130501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20130601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20130701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20130801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20130901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20131001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20131101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20131201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20140101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20140201000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20140301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20140401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20140501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20140601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20140701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20140801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20140901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20141001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20141101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20141201000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20150401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20150501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20150601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20150701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20150801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20150901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20151001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20151101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20151201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20160101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RAINNC_20160201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20160301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20160401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20160501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20160601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20160701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20160801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20160901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20161001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20161101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20161201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20170101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20170201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20170301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20170401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20170501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20170601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20170701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20170801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20170901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20171001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20171101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20171201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20180101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20180201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20180301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20180401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20180501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20180601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20180701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20180801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20180901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20181001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20181101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20181201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20190101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RAINNC_20190201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20190301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20190401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20190501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20190601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20190701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20190801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20190901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20191001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20191101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20191201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20200101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RAINNC_20200201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20200301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20200401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20200501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20200601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20200701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20200801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20200901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RAINNC_20201001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20201101000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RAINNC_20201201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20000101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RH_20000201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20000301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20000401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20000501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20000601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20000701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20000801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20000901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20001001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20001101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20001201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20010101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20010201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20010301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20010401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20010501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20010601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20010701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20010801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20010901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20011001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20011101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20011201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20020101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20020201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20020301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20020401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20020501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20020601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20020701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20020801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20020901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20021001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20021101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20021201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20030101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20030201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20030301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20030401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20030501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20030601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20030701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20030801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20030901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20031001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20031101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20031201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20040101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RH_20040201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20040301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20040401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20040501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20040601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20040701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20040801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20040901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20041001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20041101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20041201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20050101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20050201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20050301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20050401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20050501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20050601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20050701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20050801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20050901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20051001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20051101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20051201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20060101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20060201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20060301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20060401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20060501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20060601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20060701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20060801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20060901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20061001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20061101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20061201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20070101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20070201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20070301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20070401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20070501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20070601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20070701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20070801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20070901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20071001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20071101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20071201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20080101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RH_20080201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20080301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20080401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20080501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20080601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20080701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20080801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20080901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20081001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20081101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20081201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20090101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20090201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20090301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20090401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20090501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20090601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20090701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20090801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20090901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20091001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20091101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20091201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20100101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20100201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20100301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20100401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20100501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20100601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20100701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20100801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20100901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20101001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20101101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20101201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20110101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20110201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20110301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20110401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20110501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20110601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20110701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20110801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20110901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20111001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20111101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20111201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20120101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RH_20120201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20120301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20120401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20120501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20120601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20120701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20120801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20120901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20121001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20121101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20121201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20130101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20130201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20130301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20130401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20130501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20130601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20130701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20130801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20130901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20131001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20131101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20131201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20140101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20140201000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20140301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20140401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20140501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20140601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20140701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20140801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20140901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20141001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20141101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20141201000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20150401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20150501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20150601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20150701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20150801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20150901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20151001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20151101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20151201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20160101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RH_20160201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20160301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20160401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20160501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20160601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20160701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20160801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20160901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20161001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20161101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20161201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20170101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20170201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20170301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20170401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20170501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20170601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20170701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20170801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20170901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20171001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20171101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20171201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20180101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20180201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20180301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20180401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20180501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20180601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20180701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20180801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20180901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20181001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20181101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20181201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20190101000000.nc
# 308M -r--r--r-- 1 root root 308M Feb  3  2022 RH_20190201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20190301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20190401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20190501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20190601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20190701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20190801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20190901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20191001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20191101000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20191201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20200101000000.nc
# 319M -r--r--r-- 1 root root 319M Feb  3  2022 RH_20200201000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20200301000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20200401000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20200501000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20200601000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20200701000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20200801000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20200901000000.nc
# 341M -r--r--r-- 1 root root 341M Feb  3  2022 RH_20201001000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20201101000000.nc
# 330M -r--r--r-- 1 root root 330M Feb  3  2022 RH_20201201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20000101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb  3  2022 U_20000201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20000301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20000401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20000501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20000601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20000701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20000801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20000901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20001001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20001101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20001201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20010101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20010201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20010301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20010401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20010501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20010601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20010701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20010801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20010901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20011001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20011101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20011201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20020101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20020201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20020301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20020401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20020501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20020601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20020701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20020801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20020901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20021001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20021101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20021201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20030101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20030201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20030301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20030401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20030501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20030601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20030701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20030801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20030901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20031001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20031101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20031201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20040101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb  3  2022 U_20040201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20040301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20040401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20040501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20040601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20040701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20040801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20040901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20041001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20041101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20041201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20050101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20050201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20050301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20050401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20050501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20050601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20050701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20050801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20050901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20051001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20051101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20051201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20060101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20060201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20060301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20060401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20060501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20060601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20060701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20060801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20060901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20061001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20061101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20061201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20070101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20070201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20070301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20070401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20070501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20070601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20070701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20070801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20070901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20071001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20071101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20071201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20080101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb  3  2022 U_20080201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20080301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20080401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20080501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20080601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20080701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20080801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20080901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20081001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20081101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20081201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20090101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20090201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20090301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20090401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20090501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20090601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20090701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20090801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20090901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20091001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20091101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20091201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20100101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20100201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20100301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20100401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20100501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20100601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20100701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20100801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20100901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20101001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20101101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20101201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20110101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20110201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20110301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20110401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20110501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20110601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20110701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20110801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20110901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20111001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20111101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20111201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20120101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb  3  2022 U_20120201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20120301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20120401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20120501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20120601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20120701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20120801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20120901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20121001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20121101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20121201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20130101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20130201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20130301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20130401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20130501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20130601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20130701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20130801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20130901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20131001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20131101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20131201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20140101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20140201000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20140301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20140401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20140501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20140601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20140701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20140801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20140901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20141001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20141101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20141201000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20150401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20150501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20150601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20150701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20150801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20150901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20151001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20151101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20151201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20160101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb  3  2022 U_20160201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20160301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20160401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20160501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20160601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20160701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20160801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20160901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20161001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20161101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20161201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20170101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb  3  2022 U_20170201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20170301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20170401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20170501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb  3  2022 U_20170601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20170701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb  3  2022 U_20170801000000.nc
# ...
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20020501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20020601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20020701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20020801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20020901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20021001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20021101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20021201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20030101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20030201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20030301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20030401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20030501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20030601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20030701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20030801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20030901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20031001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20031101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20031201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20040101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb 14  2022 T_20040201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20040301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20040401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20040501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20040601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20040701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20040801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20040901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20041001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20041101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20041201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20050101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20050201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20050301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20050401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20050501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20050601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20050701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20050801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20050901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20051001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20051101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20051201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20060101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20060201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20060301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20060401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20060501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20060601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20060701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20060801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20060901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20061001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20061101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20061201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20070101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20070201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20070301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20070401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20070501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20070601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20070701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20070801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20070901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20071001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20071101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20071201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20080101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb 14  2022 T_20080201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20080301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20080401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20080501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20080601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20080701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20080801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20080901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20081001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20081101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20081201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20090101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20090201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20090301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20090401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20090501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20090601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20090701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20090801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20090901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20091001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20091101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20091201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20100101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20100201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20100301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20100401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20100501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20100601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20100701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20100801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20100901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20101001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20101101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20101201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20110101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20110201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20110301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20110401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20110501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20110601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20110701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20110801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20110901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20111001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20111101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20111201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20120101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb 14  2022 T_20120201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20120301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20120401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20120501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20120601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20120701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20120801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20120901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20121001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20121101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20121201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20130101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20130201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20130301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20130401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20130501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20130601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20130701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20130801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20130901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20131001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20131101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20131201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20140101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20140201000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20140301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20140401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20140501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20140601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20140701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20140801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20140901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20141001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20141101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20141201000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20150401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20150501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20150601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20150701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20150801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20150901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20151001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20151101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20151201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20160101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb 14  2022 T_20160201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20160301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20160401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20160501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20160601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20160701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20160801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20160901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20161001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20161101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20161201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20170101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20170201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20170301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20170401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20170501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20170601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20170701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20170801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20170901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20171001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20171101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20171201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20180101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20180201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20180301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20180401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20180501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20180601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20180701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20180801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20180901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20181001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20181101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20181201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20190101000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G Feb 14  2022 T_20190201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20190301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20190401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20190501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20190601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20190701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20190801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20190901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20191001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20191101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20191201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20200101000000.nc
# 3.2G -r--r--r-- 1 root root 3.2G Feb 14  2022 T_20200201000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20200301000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20200401000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20200501000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20200601000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20200701000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20200801000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20200901000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Feb 14  2022 T_20201001000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20201101000000.nc
# 3.3G -r--r--r-- 1 root root 3.3G Feb 14  2022 T_20201201000000.nc
# 2.7G -r--r--r-- 1 root root 2.7G Feb 15  2022 SMOIS_20000101000000.nc
# 341M -r--r--r-- 1 root root 341M Apr  1  2022 RAINNC_20041201000000.nc
# 341M -r--r--r-- 1 root root 341M Apr  1  2022 RAINNC_20050101000000.nc
# 330M -r--r--r-- 1 root root 330M Apr  1  2022 RAINNC_20050601000000.nc
# 341M -r--r--r-- 1 root root 341M May 31  2022 RAINNC_20150101000000.nc
# 341M -r--r--r-- 1 root root 341M May 31  2022 RH_20150101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G May 31  2022 T_20150101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G May 31  2022 U_20150101000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G May 31  2022 V_20150101000000.nc
# 308M -r--r--r-- 1 root root 308M May 31  2022 RAINNC_20150201000000.nc
# 308M -r--r--r-- 1 root root 308M May 31  2022 RH_20150201000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G May 31  2022 T_20150201000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G May 31  2022 U_20150201000000.nc
# 3.1G -r--r--r-- 1 root root 3.1G May 31  2022 V_20150201000000.nc
# 4.0K drwxr-xr-x 2 root root 4.0K Jun  1  2022 redundant_data/
# 341M -r--r--r-- 1 root root 341M Jun  1  2022 RAINNC_20150301000000.nc
# 341M -r--r--r-- 1 root root 341M Jun  1  2022 RH_20150301000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Jun  1  2022 T_20150301000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Jun  1  2022 U_20150301000000.nc
# 3.4G -r--r--r-- 1 root root 3.4G Jun  1  2022 V_20150301000000.nc

# %% [markdown]
# ### b

# %% [markdown]
# by using opetion | wc. :

# %% [markdown]
# The number of counts depends if we include redundant_data folder or not. If it is included, the count is 1,262. If it is not and we only take files with .nc, the count number is 1,261.

# %%
ls -h  /mnt/data/MetService_WRF/  | wc -l
# Out:
# 1262

# %%
ls -h  /mnt/data/MetService_WRF/*.nc  | wc -l
# Out:
# 1261

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### a

# %% [markdown]
# By loading file U_20150301000000.nc, the dataset in this file was recorded at various height level, which has 10 different heights.

# %%
import xarray as xr
ds = xr.open_dataset("/mnt/data/MetService_WRF/U_20150301000000.nc")
ds["U"] #to call the dataarray.
# Out:
# <xarray.DataArray 'U' (height: 10, time: 744, lat: 508, lon: 472)>
# [1783933440 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2015-03-01 ... 2015-03-31T23:00:00
#   * lat      (lat) float64 -48.0 -47.97 -47.94 -47.92 ... -34.06 -34.03 -34.01
#   * lon      (lon) float64 166.0 166.0 166.1 166.1 ... 178.9 178.9 179.0 179.0
#   * height   (height) float64 10.0 20.0 30.0 40.0 ... 100.0 120.0 150.0 200.0

# %% [markdown]
# ### b

# %%
#load dataset of Relative Humidity, chose the file for the Month of Jan & Year 2019
ds_rh = xr.open_dataset("/mnt/data/MetService_WRF/RH_20190101000000.nc")

# %%
#select the data near Christchurch (-43.525650, 172.639847)
Near_CHCH_rh = ds_rh.RH.sel(lat=-43.525650, lon = 172.639847, method="nearest")

# %%
#Plot Relative Humidity data for 201901, Christchurch
Near_CHCH_rh.plot(linestyle="solid", color="red", figsize=(20,5))

# %% [markdown]
# ### c

# %%
#load dataset of Air Temperature, chose the file for the Month of Jan & Year 2019
ds_at = xr.open_dataset("/mnt/data/MetService_WRF/T_20190101000000.nc")

# %%
#select the data where it has height of 20 metres above the ground
h20_at = ds_at.sel(height=20)

#select the data near Christchurch (-43.525650, 172.639847)
Near_CHCH_at = h20_at.T.sel(lat=-43.525650, lon = 172.639847, method="nearest") - 273

# %%
#Plot Air Temperature data for 201901, Christchurch
Near_CHCH_at.plot(linestyle="solid", color="red", figsize=(20,5))

# %% [markdown]
# ### d

# %% [markdown]
# #### Redo b:

# %%
# select data over 2 days from 20190103 to 20190105
Near_CHCH_rh_2days = Near_CHCH_rh.sel(time = slice("2019-01-03T0000:00.000000000","2019-01-05T00:00:00.000000000"))

# %%
#plot the Relative Humandity for selected 2 days
Near_CHCH_rh_2days.plot(linestyle="solid", color="red", figsize=(20,5))

# %% [markdown]
# #### Redo c:

# %%
# select data over 2 days from 20190103 to 20190105
Near_CHCH_at_2days = Near_CHCH_at.sel(time = slice("2019-01-03T0000:00.000000000","2019-01-05T00:00:00.000000000"))

# %%
#plot the Air Temperature for selected 2 days
Near_CHCH_at_2days.plot(linestyle="solid", color="red", figsize=(20,5))
